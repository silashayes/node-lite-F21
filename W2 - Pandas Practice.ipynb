# %%
import pandas as pd

# %%
#USE MOVIE DS
movies = pd.read_csv("https://raw.githubusercontent.com/benartuso/nodef19/master/data/02-cleaning-intro-vis/movie.csv")

# %% [markdown]
# A good idea is to always start by printing out the data set, so that you have an idea of what the data look like and how the dataframe is structured.

# %%
#do that here

# %% [markdown]
# 1. How many rows and columns are there?

# %%
#answer here

# %% [markdown]
# 2. Print the first 8 observations

# %%
#answer here

# %% [markdown]
# 3. Print the last 12 observations

# %%
#answer here

# %% [markdown]
# 4. Use the describe function on the data set

# %%
#answer here

# %% [markdown]
# 5. Sort the data set by the director's name

# %%
#answer here

# %% [markdown]
# 6. Which director has the last alphabetical name?

# %%
#answer here

# %% [markdown]
# 7. Which director has the highest number of movies?

# %%
#answer here

# %% [markdown]
# 8. Ask your own question! Type out your own question below about the data and see if you can figure it out!

# %% [markdown]
# Type your question here

# %%
#answer here
