# %% [markdown]
# # **Intro Python Notes**

# %% [markdown]
# ### Print Hello, World!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Data Types & Variables

# %%
string1 = "hello"
integer1 = 3
float1 = 3.5
boolean1 = True

#function that tells the type of the variable
type(string1)

x = int("4")
type(x)
# Out:
# int

# %%
list1 = [string1, integer1, float1, boolean1]
print(list1)
#or can output like this:
list1
# Out:
# ['hello', 3, 3.5, True]
# ['hello', 3, 3.5, True]

# %%
print(list1[0])
print(list1[1])
print(list1[3])
# Out:
# hello
# 3
# True

# %% [markdown]
# Data Type Functions

# %%
#tells the type of the variable
type(string1)

# %%
string2 = "3"

#casts variables as a specific type
now_str = str(integer1)
now_int = int(string2)

print(now_str)
print(type(now_str))
print(now_int)
print(type(now_int))
# Out:
# 3
# <class 'str'>
# 3
# <class 'int'>

# %%
#a problem with float() and int()
now_float = float(string2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-71c0779e40c0> in <module>()
#       1 #a problem with float() and int()
# ----> 2 now_float = float(string2)
#
# TypeError: 'float' object is not callable

# %%
#play around with int2 to see how it translates into a boolean
int2 = 0
now_bool = bool(int2)

print(now_bool)
print(type(now_bool))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ### Operations (Math)

# %% [markdown]
# One thing to note here is how I put str() around the math problems in the print statement. For a print statement to run, everything must be the same variable type, so in this case the integer that results needs to be casted as a string to fit our print statement

# %%
#addition
print("Addition: 3 + 4 = " + str(3+4))

#multiplication
print("Multiplication: 3 * 4 = " + str(3*4))

#subtraction
print("Subtraction: 3 - 4 = " + str(3-4))

#exponent
print("Exponent: 3^2 = " + str(3**2))

#division
print("Division: 4 / 3 = " + str(4/3))

#int division
print("Int Division: 4 // 3 = " + str(4//3))

#remainder
print("Remainder: 4 % 3 = " + str(4%3))
# Out:
# Addition: 3 + 4 = 7
# Multiplication: 3 * 4 = 12
# Subtraction: 3 - 4 = -1
# Exponent: 3^2 = 9
# Division: 4 / 3 = 1.3333333333333333
# Int Division: 4 // 3 = 1
# Remainder: 4 % 3 = 1

# %% [markdown]
# ### Comparisons/Conditionals

# %%
#compare values
print(3>4) #greater than - False
print(3<=4) #less than or equal to - True
print(3==3) #equals - True
print(3!=4) #does not equal - True

# %%
#add logic to comparisons
print(3>4 and 2<3) #and - False
print(3>4 or 2<3) #or - True
print(not 3==3) #not - False

# %%
#conditionals build complex comparisons with different outputs
x = 4 #change this value and see outcome
if(x>3 and x<6):
  print("Tony")
elif(x==3):
  print("Bennett")
else:
  print("loves you")
# Out:
# False
# True
# False
# True
# True
# True
# _____________________
# False
# True
# False
# _____________________
# hackcville
# _____________________
# Carter is a student.

# %%
#A different approach
champion = True
if(champion):
  print("Tony Bennett loves you")
else:
  print("Tony Bennett still loves you")
# Out:
# Tony Bennett loves you
